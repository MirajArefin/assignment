# %%
import math
data = [[0,.05,.09,.15,.20,.24,.29,.33,.39,.43,.49,.52,.61,.61,.61,.61,.61,.61],
        [0,.07,.12,.20,.24,.29,.32,.38,.45,.51,.61,.68,.75,.77,.77,.77,.77,.77],
        [0,.08,.16,.24,.31,.39,.45,.54,.59,.65,.69,.75,.81,.84,.89,.92,.92,.92,.92],
        [0,.11,.19,.25,.30,.38,.46,.53,.60,.67,.71,.77,.83,.89,.94,.99,1.1,1.1,1.1],
        [0,.14,.25,.31,.37,.42,.49,.54,.59,.65,.72,.79,.81,.88,.95,1.2,1.4,1.5,1.5]]
v_stream = [.61,.77,.92,1.1,1.5]
v_alpha = [.035, .039,.042,.048,.053]
del1 = [6,6.5,7,7.5,8.5]
for epoch in range(5):
    print("For observation no -", epoch + 1, ":")
#     print("Free stream velocity V = ")
    for i in range(18):
        print("(" + str(i+1) + ")", "Y"+ str(i), "=", i/2, "mm")
        print("\t\t_P" + str(i), "=", data[epoch][i], "KPa")
        temp = math.sqrt((2 * v_stream[epoch] * .001 * data[epoch][i]) / (1.172 * .57))
        print("\t\tV{0} = {1}".format(i, round(temp, 3)))
        print("\t\tV{0}/V~ = {1}".format(i, round(temp/v_alpha[epoch], 3)))
        print("\t\tY{0}/del{1} = {2}".format(i, epoch, round((i/2)/del1[epoch], 3)))
        print()
# Out:
# For observation no - 1 :
# (1) Y0 = 0.0 mm
# 		_P0 = 0 KPa
# 		V0 = 0.0
# 		V0/V~ = 0.0
# 		Y0/del0 = 0.0
#
# (2) Y1 = 0.5 mm
# 		_P1 = 0.05 KPa
# 		V1 = 0.01
# 		V1/V~ = 0.273
# 		Y1/del0 = 0.083
#
# (3) Y2 = 1.0 mm
# 		_P2 = 0.09 KPa
# 		V2 = 0.013
# 		V2/V~ = 0.366
# 		Y2/del0 = 0.167
#
# (4) Y3 = 1.5 mm
# 		_P3 = 0.15 KPa
# 		V3 = 0.017
# 		V3/V~ = 0.473
# 		Y3/del0 = 0.25
#
# (5) Y4 = 2.0 mm
# 		_P4 = 0.2 KPa
# 		V4 = 0.019
# 		V4/V~ = 0.546
# 		Y4/del0 = 0.333
#
# (6) Y5 = 2.5 mm
# 		_P5 = 0.24 KPa
# 		V5 = 0.021
# 		V5/V~ = 0.598
# 		Y5/del0 = 0.417
#
# (7) Y6 = 3.0 mm
# 		_P6 = 0.29 KPa
# 		V6 = 0.023
# 		V6/V~ = 0.658
# 		Y6/del0 = 0.5
#
# (8) Y7 = 3.5 mm
# 		_P7 = 0.33 KPa
# 		V7 = 0.025
# 		V7/V~ = 0.701
# 		Y7/del0 = 0.583
#
# (9) Y8 = 4.0 mm
# 		_P8 = 0.39 KPa
# 		V8 = 0.027
# 		V8/V~ = 0.763
# 		Y8/del0 = 0.667
#
# (10) Y9 = 4.5 mm
# 		_P9 = 0.43 KPa
# 		V9 = 0.028
# 		V9/V~ = 0.801
# 		Y9/del0 = 0.75
#
# (11) Y10 = 5.0 mm
# 		_P10 = 0.49 KPa
# 		V10 = 0.03
# ...
